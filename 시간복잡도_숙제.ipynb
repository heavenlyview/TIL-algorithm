# %% [markdown]
# <a href="https://colab.research.google.com/github/heavenlyview/TIL-algorithm/blob/master/%EC%8B%9C%EA%B0%84%EB%B3%B5%EC%9E%A1%EB%8F%84_%EC%88%99%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 출처:
# - https://shacoding.com/2021/04/01/%EC%9E%90%EB%A3%8C%EA%B5%AC%EC%A1%B0%EC%99%80-%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98-%EC%8B%9C%EA%B0%84%EB%B3%B5%EC%9E%A1%EB%8F%84/
#
# - https://kindjm.tistory.com/71
#
# - https://velog.io/@seungmini/%EA%B0%9C%EB%85%90%EC%A0%95%EB%A6%AC-%EC%8B%9C%EA%B0%84-%EB%B3%B5%EC%9E%A1%EB%8F%84

# %% [markdown]
# # 시간 복잡도 (Time Comlexity)
#
# 입력의 개수가 n개일 때, 알고리즘 실행 시간을 n에 대한 함수로 표현한 것
# (보통 가장 연산을 많이 해야 되는 경우로 함수를 표현한다)
#
# **실행시간**이라는 관점에서 알고리즘의 효율을 측정하는 **표기법**

# %% [markdown]
# ## 표기법의 종류
#
# 1. 최상의 경우: 오메가 표기법 (Big-Ω Notation)
# 2. 평균의 경우: 세타 표기법 (Big-θ Notation)
# 3. **최악의 경우: 빅오 표기법 (Big-O Notation)**
#
# 일반적으로 최악의 경우를 고려한 **빅오 표기법**을 사용

# %% [markdown]
# ## 그럼 빅오 표기법은 뭘까?
#
# **Big-O 표기법**
# - 알고리즘의 전체 단계를 **대수 용어**로 변환한 다음 문제의 전체 복잡성에 **큰 영향을 미치지 않는** 하위 상수 및 계수를 **제외**하는 방법
#   - 개발자들이 시간을 절약하기 위해 방식을 단순화하여 사용

# %% [markdown]
# 중요 포인트: 복잡도를 간소화하여 나타내는 표기법

# %% [markdown]
# 예제
# ```
# Regular        Big-O
#
# 2              O(1)     -> It's just a constant number
#
# 2n + 10        O(n)     -> n has the largest effect
#
# 5n^2           O(n^2)   -> n^2 has the largest effect
# ```
#
# ``2``: 반복문이 아닌 단순한 문장으로 실행문은 O(1)로 표기
#
# ``2n + 10``: 루프문의 시작에서 n까지의 반복은 O(n)으로 2n + 10 으로 알고리즘이 분석되어도 O(n)
#
# ``5n^2``: 루프문이 2개의 중첩을 가지고 있다면 O(n^2)로 된다. ``5n^2``와 같이 알고리즘이 나오면 O(n^2)

# %% [markdown]
# **O(1) 알고리즘**
# - 입력 데이터의 크기와 상관없이 언제나 일정한 시간이 걸리는 알고리즘
#   - 입력값이 증가하더라도 시간이 **늘어나지 않는다**
#   - 입력값의 **크기와 관계없이** 즉시 출력값을 얻어낼 수 있다
# ![캡처.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **O(log n) 알고리즘**
# - 빅오 표기법 중 **O(1)** 다음으로 빠른 시간 복잡도
#   - 자료구조에서 BST (Binary Search Tree) 값 탐색에서 O(log n)의 시간복잡도를 가진 알고리즘
#   - 매번 숫자를 제시할 때마다 경우의 수가 절반이 줄어들기 때문에 최악의 경우에도 1 ~ 100 중에 하나를
# 찾아낼때 7번이면 원하는 숫자를 손에 넣을 수 있다
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **O(n)** 알고리즘
# - 입력데이터의 **크기**에 비례해서 **처리시간이 증가**하는 알고리즘
#   - 예를들어 입력값이 1일때 1초의 시간이 걸리고 입력값을 100배로 증가시켰을 때 시간도 100배 증가하는
# 알고리즘을 구현했다면, 그 알고리즘은 **O(n)**의 시간복잡도를 가진다
#   - 입력값이 커지면 커질수록 계수(n 앞에 있는 수)의 의미(영향력)가 점점 퇴색되기 때문에,
# 같은 비율로 증가하고 있다면 2배가 아닌 5배, 10배로 증가하더라도 **O(n)**으로 표기
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **O(n^2) 알고리즘**
# - 입력값이 증가함에 따라 **시간이 n의 제곱수의 비율로 증가**하는것
#   - 예를들어 입력값이 1일경우 1초가 걸리던 알고리즘에 5라는 값을 주었더니 25초가 걸리게 된다면
# 이 알고리즘의 시간복잡도는 **O(n^2)** 라고 표현
#   - 2n, 5n 을 모두 O(n)이라고 표현하는 것처럼, n^3과 n^5 도 모두** O(n^2)**로 표기합니다. n이 커지면 커질수록 지수가 주는 영향력이 점점 퇴색되기 때문에
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **O(2^n)** 알고리즘
# - 빅오 표기법 중에서 **가장 느린** 시간복잡도
#   - 구현한 알고리즘의 시간복잡도가 **O(2^n)** 이라면 다른 접근방식을 고려해보자
#   - **피보나치 수열**은 O(2^n) 의 시간복잡도를 가진 대표적인 알고리즘
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 시간 복잡도를 구하는 요령
#
# - 하나의 루프를 사용하여 단일 요소 집합을 반복하는 경우: **O(n)**
# - 컬렉션의 절반 이상을 반복하는 경우: O(n/2) -> **O(n)**
# - 두 개의 다른 루프를 사용하여 두 개의 개별 콜렉션을 반복할 경우: O(n+m) -> **O(n)**
# - 두 개의 중첩 루프를 사용하여 단일 컬렉션을 반복하는 경우: **O(n^2)**
# - 두 개의 중첩 루프를 사용하여 두 개의 다른 콜렉션을 반복할 경우: O(n * m) ->  **O(n^2)**
